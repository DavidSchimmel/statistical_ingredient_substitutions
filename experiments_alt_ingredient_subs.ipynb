# %% [markdown]
# - calculate the other metric (use the util file)
# - maybe calculate the third metric as well, but need to be able to map the ingredients to categories
# ---
# - distance metrics:
#   - cosine
#   - euclidean
#   - Hemming (?? because they suggested that in their paper but how does that make sense?)
# - normalization
#   - entire matrix
#   - each ingredient
#   - all subst for an ingredient
#   - try to balance the overrepresented ingredients such as salt, butter, meal:
#     - log before normalization
#     - gumbel softmax activation
# - maybe filter out over- and underrepresented ingredients
# - What do we measure?
#   - GT rank
#   - select some recipe and see where we get better substitutions (like qualitatively?)

# %%
import os
import pickle
import pandas as pd

from calc_recipe_ingredient_info_distances import collectSomeRecipeRecommendations, get_all_comments, get_all_mutual_info, evalRecommendations, getRecommendationsBasedOnMutualInformationRole, get_graph_nodes, get_all_gt_recipes, get_recipes_per_ingredient, get_recipes_per_ingredient_pairs, get_all_frequencies,getNaiveBayesRecommendations

# %%
ORDERED_RECIPE_IDS_PATH = os.path.abspath("./outputs/sorted_recipe_ids_list.pkl")
TRAIN_COMMENTS_PATH = os.path.abspath("./inputs/train_comments_subs.pkl") # train recipes with substitutions
TEST_COMMENTS_PATH = os.path.abspath("./inputs/test_comments_subs.pkl") # test recipes with substitutions
VAL_COMMENTS_PATH = os.path.abspath("./inputs/val_comments_subs.pkl") # validation recipes with substitutions
GRAPH_NODES_PATH = os.path.abspath("./inputs/graph/nodes_191120.csv")

MUTUAL_INFO_DICT_PATH = os.path.abspath("./outputs/mutual_info_dict_with_self_info.pkl")
RECIPES_PER_INGREDIENT_SMALL_PATH = os.path.abspath(
    "./outputs/recipes_per_ingredient_small.pkl"
)
RECIPES_PER_INGREDIENT_PAIRS_SMALL_PATH = os.path.abspath(
    "./outputs/recipes_per_ingredient_pairs_small.pkl"
)
PROCESSED_RECIPES_PATH = os.path.abspath("./outputs/processed_recipes.pkl")

# %% [markdown]
# # load all the data

# %%
if os.path.isfile(ORDERED_RECIPE_IDS_PATH):
    with open(ORDERED_RECIPE_IDS_PATH, "rb") as file:
        ordered_recipe_ids = pickle.load(file)
recipe_ids_with_ranks = ordered_recipe_ids
ordered_recipe_ids = [recipe[1] for recipe in recipe_ids_with_ranks]

# recipes with comments, lists, names, and gt_truths
extended_recipes = get_all_comments(TRAIN_COMMENTS_PATH, TEST_COMMENTS_PATH, VAL_COMMENTS_PATH)
recipes_extended_dict = {recipe["id"]:recipe for recipe in extended_recipes}


# recipe ingredient df one hot
# INGREDIENT_RECIPE_MATRIX_PATH = os.path.abspath("./outputs/ingredient_recipe_matrix.pkl")
# recipe_ingredient_df = get_recipe_ingredient_df( ingredients, recipes, recipes_per_ingredient, INGREDIENT_RECIPE_MATRIX_PATH)
# recipe_ingredient_df_bool = recipe_ingredient_df.astype(bool)

with open(MUTUAL_INFO_DICT_PATH, "rb") as mutual_info_dict_file:
            mutual_info_dict = pickle.load(mutual_info_dict_file)

ingredients = get_graph_nodes(GRAPH_NODES_PATH)

recipes = get_all_gt_recipes(TRAIN_COMMENTS_PATH, TEST_COMMENTS_PATH,
                                VAL_COMMENTS_PATH, PROCESSED_RECIPES_PATH)
recipes_per_ingredient = get_recipes_per_ingredient(
    ingredients, recipes, RECIPES_PER_INGREDIENT_SMALL_PATH)

recipes_per_ingredient_pairs = get_recipes_per_ingredient_pairs(
    recipes_per_ingredient, RECIPES_PER_INGREDIENT_PAIRS_SMALL_PATH)
recipe_ingredient_counts, recipe_ingredient_pair_counts = get_all_frequencies(recipes_per_ingredient,
                                        recipes_per_ingredient_pairs)

# %% [markdown]
# ## Set some additional helper functions

# %%
def getRecipeFromComments(recipeId, allComments):
    recipe = None
    for commentRecipe in allComments:
        gt_ingredient_found = False
        comment_recipe_id = commentRecipe['id']
        if recipeId == comment_recipe_id:
            if recipe is None:
                recipe = {}
                recipe["id"] = comment_recipe_id
                recipe["subs"] = []
                recipe["ingredients"] = commentRecipe["ingredients"]

            if recipe is not None:
                recipe["subs"].append(commentRecipe["subs"])

    return recipe

# %%
def getRanksFromDirectRecommendations(source_ingredients, recommendations, extended_recipes, offset = -1):
    gt_ranks = []
    for recipe_id, recipe_recommendations in recommendations.items():
        recipe = getRecipeFromComments(recipe_id, extended_recipes)
        gt_subs = [sub[1] for sub in  recipe["subs"] if sub[0] == source_ingredients[recipe_id]] # get all valid substitutions for the source ingredient in the recipe
        recipe_recommendations = list(recipe_recommendations.keys())
        for i, ingredient in enumerate(recipe_recommendations):
            if ingredient in gt_subs:
                gt_ranks.append(i + offset) # to set off the top ranking self-recommendation
                gt_ingredient_found = True
                break
        if not gt_ingredient_found:
            gt_ranks.append(i)
    return gt_ranks

def getRanksFromRecommendationTuples(source_ingredients, recommendations_tuples, extended_recipes, offset = -1):
    # gt_ranks = []
    # for recipe_id, recommendations_tuples in recommendations_tuples.items():
    #     recipe = getRecipeFromComments(recipe_id, extended_recipes)
    #     gt_subs = [sub[1] for sub in  recipe["subs"]]
    #     recommendations = [tuple[0] for tuple in recommendations_tuples]
    #     for i, ingredient in enumerate(recommendations):
    #         if ingredient in gt_subs:
    #             gt_ranks.append(i-1) # to set off the top ranking self-recommendation
    #             continue
    gt_ranks = []
    for recipe_id, recipe_recommendations_tuples in recommendations_tuples.items():
        gt_ingredient_found = False
        recipe = getRecipeFromComments(recipe_id, extended_recipes)
        gt_subs = [sub[1] for sub in  recipe["subs"] if sub[0] == source_ingredients[recipe_id]] # get all valid substitutions for the source ingredient in the recipe
        recommendations = [tuple[0] for tuple in recipe_recommendations_tuples]
        for i, ingredient in enumerate(recommendations):
            if ingredient in gt_subs:
                gt_ranks.append(i + offset) # to set off the top ranking self-recommendation
                gt_ingredient_found = True
                break
        if not gt_ingredient_found:
            gt_ranks.append(i)
            
    return gt_ranks

def compare_recommendation_ranks(recommendation_ranks_1, recommendation_ranks_2, tolerance=10):
    rec_1_better = []
    rec_2_better = []
    both_equal = []
    
    for i in range(len(recommendation_ranks_1)):
        if recommendation_ranks_1[i] < recommendation_ranks_2[i] - tolerance:
            rec_1_better.append(i)
        elif recommendation_ranks_2[i] < recommendation_ranks_1[i] - tolerance:
            rec_2_better.append(i)
        else:
            both_equal.append(i)
    return rec_1_better, rec_2_better, both_equal

def get_gt_hits_at_k(k, recommendation_ranks):
    hits_at_k = []
    for i, rank in enumerate(recommendation_ranks):
        if rank <= k:
            hits_at_k.append(i)
    return hits_at_k

# %% [markdown]
# ## Get Measure for examplary recipe

# %%
recipe_ids = ["a21302e305"]
recipe_id = recipe_ids[0]

recip = getRecipeFromComments(recipe_id, extended_recipes)

bayes_naive_recommendations = getNaiveBayesRecommendations(recipe_ids, extended_recipes, recipe_ingredient_counts, recipe_ingredient_pair_counts)

direct_source_mutual_info_recommendations, cosine_similarity_role_recommendations, euclidean_similarity_role_recommendations, manhatten_similarity_role_recommendations = getRecommendationsBasedOnMutualInformationRole(recipe_ids, extended_recipes, mutual_info_dict)

_, cosine_similarity_role_recommendations_sq, euclidean_similarity_role_recommendations_sq, manhatten_similarity_role_recommendations_sq = getRecommendationsBasedOnMutualInformationRole(recipe_ids, extended_recipes, mutual_info_dict, normalization="dampen_square")

_, cosine_similarity_role_recommendations_minimax, euclidean_similarity_role_recommendations_minimax, manhatten_similarity_role_recommendations_minimax = getRecommendationsBasedOnMutualInformationRole(recipe_ids, extended_recipes, mutual_info_dict, normalization="minmax")

_, _2, euclidean_similarity_role_recommendations_ind_squared, manhatten_similarity_role_recommendations_ind_squared = getRecommendationsBasedOnMutualInformationRole(recipe_ids, extended_recipes, mutual_info_dict, normalization=None, limiter_indiv_ingr_distance="squared")

print(f"gt_sub = ({recip['subs']})  direct_mi = {list(direct_source_mutual_info_recommendations[recipe_ids[0]].items())[:15]}")

print(cosine_similarity_role_recommendations[recipe_ids[0]][:15])
print(euclidean_similarity_role_recommendations[recipe_ids[0]][:15])
print(manhatten_similarity_role_recommendations[recipe_ids[0]][:15])
print("===")
print(cosine_similarity_role_recommendations_sq[recipe_ids[0]][:15])
print(euclidean_similarity_role_recommendations_sq[recipe_ids[0]][:15])
print(manhatten_similarity_role_recommendations_sq[recipe_ids[0]][:15])
print("===")
print(cosine_similarity_role_recommendations_minimax[recipe_ids[0]][:15])
print(euclidean_similarity_role_recommendations_minimax[recipe_ids[0]][:15])
print(manhatten_similarity_role_recommendations_minimax[recipe_ids[0]][:15])
print("===")
print(euclidean_similarity_role_recommendations_ind_squared[recipe_ids[0]][:15])
print(manhatten_similarity_role_recommendations_ind_squared[recipe_ids[0]][:15])

print("test done")
# Out:
# gt_sub = ([('all_purpose_flour', 'ground_almond'), ('slivered_almond', 'vanilla_extract')])  direct_mi = [('sesame_seed', 0.0005614077755832065), ('almond_extract', 0.0005543576357978351), ('dried_cranberry', 0.0005173229393879747), ('sunflower_seed', 0.0004646666895138482), ('green_onion', 0.000387135342628955), ('golden_raisin', 0.00036371327039129734), ('mayonnaise', 0.0003435368202518623), ('raisin', 0.00033235923284172415), ('mandarin_orange', 0.0003275299028412627), ('honey', 0.00028803808116346485), ('potato', 0.0002851576348480364), ('wheat_germ', 0.0002800274747300018), ('chicken_flavored_ramen_noodle', 0.0002798483709266614), ('couscous', 0.00027772200881617153), ('coleslaw', 0.00026976525704042274)]
# [('slivered_almond', 0.9999999999999999), ('fresh_cherry', 0.9878396139150007), ('cookie_cutter', 0.9819123568814901), ('peach_pie_filling', 0.9802743916725406), ('cinnamon_roll', 0.9768896656617706), ('almond', 0.9727307419359852), ('non_dairy_milk_substitute', 0.9707644823031891), ('seedless_red_raspberry_jam', 0.9691131573497701), ('tart_red_cherry', 0.966361652693119), ('tart_cherry', 0.9649058359403377), ('chocolate_fudge_frosting', 0.9641487920422561), ('whole_almond', 0.9627597195373181), ('chocolate_flavored_liqueur', 0.9625406502373862), ('peach_juice', 0.9607230863214702), ('guava', 0.9571674747151947)]
# [('slivered_almond', 0.0), ('tart_cherry', 0.00023438026501096577), ('toasted_sliced_almond', 0.00024962851278625075), ('seedless_raspberry_jam', 0.0002953631879205856), ('raspberry_jam', 0.00031423643971377425), ('whole_almond', 0.0003198310722465865), ('red_food_coloring', 0.000326051436655373), ('blanched_almond', 0.00035300497412226947), ('almond_paste', 0.0003566042117691798), ('amaretto_liqueur', 0.0003566572616725368), ('fresh_cherry', 0.00036920872871273105), ('red_maraschino_cherry', 0.00039436430933852677), ('sweetened_condensed_milk', 0.000397516165142151), ('blueberry_preserve', 0.0004093409369254786), ('coffee_flavored_liqueur', 0.0004130551647193251)]
# [('slivered_almond', 0.0), ('tart_cherry', 0.0004886088637613126), ('toasted_sliced_almond', 0.0005482472589684926), ('whole_almond', 0.0005706305344806147), ('fresh_cherry', 0.0006192420599683526), ('red_food_coloring', 0.0006463639065533688), ('blanched_almond', 0.0006542832231609596), ('rutabaga', 0.0006757026955970101), ('italian_style_breadcrumb', 0.0006844027794514904), ('candied_orange_peel', 0.0006887527166592376), ('quick_cooking_tapioca', 0.0006995430979792281), ('coffee_flavored_liqueur', 0.0007001597492070821), ('fat_free_low_sodium_chicken_broth', 0.0007017288812939924), ('pink_salmon', 0.0007022065822060544), ('texas_toast_thick_bread', 0.0007072579365454483)]
# ===
# [('slivered_almond', 1.0000000000000002), ('tart_cherry', 0.9984560890248396), ('almond', 0.99818332239684), ('cookie_cutter', 0.9980766526479741), ('fresh_cherry', 0.9980535014180971), ('cinnamon_roll', 0.9979201556872349), ('tart_red_cherry', 0.9978928938835778), ('peach_pie_filling', 0.9978730373720127), ('peppermint_candy', 0.9975997006524162), ('non_dairy_milk_substitute', 0.9975934736862467), ('seedless_red_raspberry_jam', 0.9973908316448942), ('toasted_sliced_almond', 0.9970555448570622), ('peach_juice', 0.9969830572225324), ('liquid', 0.9969521000449247), ('chocolate_flavored_liqueur', 0.996762671071719)]
# [('slivered_almond', 0.0), ('ground_almond', 1.500633547033416e-07), ('red_food_coloring', 1.5229037017068515e-07), ('tart_cherry', 1.6006370570169505e-07), ('toasted_sliced_almond', 1.6203738449245082e-07), ('seedless_raspberry_jam', 1.8694664751760762e-07), ('raspberry_jam', 1.8870271899377987e-07), ('almond_paste', 2.2267496287297243e-07), ('green_food_coloring', 2.3128636595560743e-07), ('whole_almond', 2.3718647883236822e-07), ('sweetened_condensed_milk', 2.385027779359731e-07), ('amaretto_liqueur', 2.541154263920349e-07), ('blanched_almond', 2.5588192770390554e-07), ('fresh_cherry', 2.5973201319909235e-07), ('blueberry_preserve', 2.6507067944794703e-07)]
# [('slivered_almond', 0.0), ('tart_cherry', 1.9575068550096658e-07), ('toasted_sliced_almond', 2.043394487737485e-07), ('red_food_coloring', 2.1964541328885586e-07), ('seedless_raspberry_jam', 2.46610825446484e-07), ('raspberry_jam', 2.5860440441542746e-07), ('whole_almond', 2.710535852513301e-07), ('ground_almond', 2.8973288378748395e-07), ('blanched_almond', 2.901367567255957e-07), ('almond_paste', 2.911428691588451e-07), ('amaretto_liqueur', 2.9939318187645176e-07), ('fresh_cherry', 3.0081720010588057e-07), ('red_maraschino_cherry', 3.1103231711034244e-07), ('amaretto', 3.1834290244963185e-07), ('candied_orange_peel', 3.1955132806878e-07)]
# ===
# [('slivered_almond', 1.0), ('fresh_cherry', 0.9878396139150005), ('cookie_cutter', 0.98191235688149), ('peach_pie_filling', 0.9802743916725405), ('cinnamon_roll', 0.9768896656617709), ('almond', 0.9727307419359853), ('non_dairy_milk_substitute', 0.9707644823031893), ('seedless_red_raspberry_jam', 0.9691131573497702), ('tart_red_cherry', 0.9663616526931189), ('tart_cherry', 0.9649058359403379), ('chocolate_fudge_frosting', 0.9641487920422562), ('whole_almond', 0.962759719537318), ('chocolate_flavored_liqueur', 0.9625406502373862), ('peach_juice', 0.9607230863214702), ('guava', 0.9571674747151947)]
# [('slivered_almond', 0.0), ('tart_cherry', 0.42279613353506695), ('toasted_sliced_almond', 0.4503022898331397), ('seedless_raspberry_jam', 0.5328025968209071), ('raspberry_jam', 0.5668478603375297), ('whole_almond', 0.5769399600427323), ('red_food_coloring', 0.5881608110008576), ('blanched_almond', 0.636782018189796), ('almond_paste', 0.6432746457184678), ('amaretto_liqueur', 0.6433703418899126), ('fresh_cherry', 0.6660118033394876), ('red_maraschino_cherry', 0.7113896947968529), ('sweetened_condensed_milk', 0.7170752948501252), ('blueberry_preserve', 0.7384058782492506), ('coffee_flavored_liqueur', 0.7451059353134974)]
# [('slivered_almond', 0.0), ('tart_cherry', 0.8813964708145557), ('toasted_sliced_almond', 0.9889775544977417), ('whole_almond', 1.0293545134619815), ('fresh_cherry', 1.1170443410184756), ('red_food_coloring', 1.1659691592831), ('blanched_almond', 1.1802547325235468), ('rutabaga', 1.2188930970970289), ('italian_style_breadcrumb', 1.2345870882909251), ('candied_orange_peel', 1.242433894985464), ('quick_cooking_tapioca', 1.2618985521367287), ('coffee_flavored_liqueur', 1.263010922902519), ('fat_free_low_sodium_chicken_broth', 1.2658414640290103), ('pink_salmon', 1.266703183758683), ('texas_toast_thick_bread', 1.27581526955529)]
# ===
# [('slivered_almond', 0.0), ('tart_cherry', 3.318914745392347e-08), ('toasted_sliced_almond', 3.479439595751792e-08), ('seedless_raspberry_jam', 4.58659350959581e-08), ('raspberry_jam', 5.3289921342645375e-08), ('almond_paste', 7.248968143769184e-08), ('red_food_coloring', 7.301875695210805e-08), ('whole_almond', 8.407524298565232e-08), ('sweetened_condensed_milk', 8.982783616264781e-08), ('green_food_coloring', 9.237875460078132e-08), ('amaretto_liqueur', 1.041658435714368e-07), ('blanched_almond', 1.069377626479736e-07), ('maraschino_cherry', 1.0869500735159074e-07), ('fresh_cherry', 1.1224696357946357e-07), ('blueberry_preserve', 1.2105709571699721e-07)]
# [('slivered_almond', 0.0), ('tart_cherry', 5.493410862661052e-08), ('toasted_sliced_almond', 6.231439439587538e-08), ('seedless_raspberry_jam', 8.723941277861102e-08), ('raspberry_jam', 9.874454004398851e-08), ('whole_almond', 1.022919147744013e-07), ('red_food_coloring', 1.063095393450325e-07), ('blanched_almond', 1.246125117550641e-07), ('almond_paste', 1.2716656385151795e-07), ('amaretto_liqueur', 1.272044023037524e-07), ('fresh_cherry', 1.3631508535767097e-07), ('red_maraschino_cherry', 1.5552320848005332e-07), ('sweetened_condensed_milk', 1.580191015493218e-07), ('blueberry_preserve', 1.675600026430287e-07), ('coffee_flavored_liqueur', 1.7061456910130881e-07)]
# test done

# %%
source_ingredients = {recipe_id: recommendations[0][0] for recipe_id, recommendations in cosine_similarity_role_recommendations.items()}

gt_ranks_mi_direct = getRanksFromDirectRecommendations(source_ingredients, direct_source_mutual_info_recommendations, extended_recipes, 0)
gt_ranks_mi_cosine_role = getRanksFromRecommendationTuples(source_ingredients, cosine_similarity_role_recommendations, extended_recipes, -1)
gt_ranks_mi_euclid_role = getRanksFromRecommendationTuples(source_ingredients, euclidean_similarity_role_recommendations, extended_recipes, -1)
gt_ranks_mi_manhat_role = getRanksFromRecommendationTuples(source_ingredients, manhatten_similarity_role_recommendations, extended_recipes, -1)

direct_better_than_cosine, cosine_better_than_direct, cosine_equal_direct = compare_recommendation_ranks(gt_ranks_mi_direct, gt_ranks_mi_cosine_role, tolerance=15)
direct_better_than_euclid, euclid_better_than_direct, euclid_equal_direct = compare_recommendation_ranks(gt_ranks_mi_direct, gt_ranks_mi_euclid_role, tolerance=15)
direct_better_than_manhat, manhat_better_than_direct, manhat_equal_direct = compare_recommendation_ranks(gt_ranks_mi_direct, gt_ranks_mi_manhat_role, tolerance=15)

hits_at_15_direct = get_gt_hits_at_k(15, gt_ranks_mi_direct)
hits_at_15_cosine = get_gt_hits_at_k(15, gt_ranks_mi_cosine_role)
hits_at_15_euclid = get_gt_hits_at_k(15, gt_ranks_mi_euclid_role)
hits_at_15_manhat = get_gt_hits_at_k(15, gt_ranks_mi_manhat_role)

# %% [markdown]
# ## Compare GT Ranks for several recipes

# %%
ingredients = get_graph_nodes(GRAPH_NODES_PATH)
recipe_ids = []
for i, recipe_id in enumerate(list(recipes_extended_dict.keys())):
    if i % 500 == 0:
        recipe = getRecipeFromComments(recipe_id, extended_recipes)
        recipe_ids.append(recipe_id)

# %%
direct_source_mutual_info_recommendations, cosine_similarity_role_recommendations, euclidean_similarity_role_recommendations, manhatten_similarity_role_recommendations = getRecommendationsBasedOnMutualInformationRole(recipe_ids, extended_recipes, mutual_info_dict)

source_ingredients = {recipe_id: recommendations[0][0] for recipe_id, recommendations in cosine_similarity_role_recommendations.items()}

gt_ranks_direct_mi = []
gt_ranks_mi_cosine_role = []
gt_ranks_mi_euclid_role = []
gt_ranks_mi_manhat_role = []

# for recipe_id, recommendations in direct_source_mutual_info_recommendations.items():
#     recipe = getRecipeFromComments(recipe_id, extended_recipes)
#     gt_subs = [sub[1] for sub in  recipe["subs"]]
#     for i, ingredient in enumerate(list(recommendations.keys())):
#         if ingredient in gt_subs:
#             gt_ranks_direct_mi.append(i)
#             continue

gt_ranks_direct_mi = getRanksFromDirectRecommendations(source_ingredients, direct_source_mutual_info_recommendations, extended_recipes, 0)
getRecommendationsBasedOnMutualInformationRole(recipe_ids, extended_recipes, mutual_info_dict, normalization="dampen_square")

_, cosine_similarity_role_recommendations_minimax, euclidean_similarity_role_recommendations_minimax, manhatten_similarity_role_recommendations_minimax = getRecommendationsBasedOnMutualInformationRole(recipe_ids, extended_recipes, mutual_info_dict, normalization="minmax")

gt_ranks_mi_cosine_role_sq_damp = getRanksFromRecommendationTuples(source_ingredients, cosine_similarity_role_recommendations_sq_damp, extended_recipes)
gt_ranks_mi_euclid_role_sq_damp = getRanksFromRecommendationTuples(source_ingredients, euclidean_similarity_role_recommendations_sq_damp, extended_recipes)
gt_ranks_mi_manhat_role_sq_damp = getRanksFromRecommendationTuples(source_ingredients, manhatten_similarity_role_recommendations_sq_damp, extended_recipes)
gt_ranks_mi_cosine_role_minimax = getRanksFromRecommendationTuples(source_ingredients, cosine_similarity_role_recommendations_minimax, extended_recipes)
gt_ranks_mi_euclid_role_minimax = getRanksFromRecommendationTuples(source_ingredients, euclidean_similarity_role_recommendations_minimax, extended_recipes)
gt_ranks_mi_manhat_role_minimax = getRanksFromRecommendationTuples(source_ingredients, manhatten_similarity_role_recommendations_minimax, extended_recipes)


print(gt_ranks_mi_cosine_role_sq_damp)
print(gt_ranks_mi_euclid_role_sq_damp)
print(gt_ranks_mi_manhat_role_sq_damp)
print("===")
print(gt_ranks_mi_cosine_role_minimax)
print(gt_ranks_mi_euclid_role_minimax)
print(gt_ranks_mi_manhat_role_minimax)
# Out:
# [56, 2588, 663, 4808, 611, 3348, 4283, 4817, 61, 60, 527, 203, 1562, 1832, 1142, 3369, 2505, 5479, 4268, 160, 765, 1167, 5317, 888, 3185, 1325, 1252, 6652, 206, 5803, 52, 1352, 131, 5203, 6652, 5114, 4989, 3531, 369, 2120, 966, 1317, 4837, 2749, 1806, 1612, 4121, 157, 5440, 1161, 65, 5812, 45, 5756, 74, 5528, 4295, 28, 5260, 3287, 5529, 2766, 132, 5727, 1895, 3830, 2626, 1960, 3176, 4985, 275, 6652, 19, 6652, 2174, 5234, 2889, 2207, 6005, 1007, 3005, 87, 1068, 4591, 72, 519, 3460, 112, 3348]
# [255, 6413, 128, 6338, 2332, 48, 6456, 1544, 4, 202, 31, 394, 4, 99, 6613, 181, 4613, 3419, 363, 6615, 6635, 37, 6244, 80, 6628, 6589, 6543, 6652, 6629, 6584, 26, 6623, 6647, 5126, 6652, 6490, 5609, 509, 23, 6, 664, 6637, 6609, 21, 6443, 2231, 3294, 3307, 6458, 301, 4, 6631, 6477, 6436, 0, 2871, 6360, 56, 6289, 6381, 264, 6637, 29, 6566, 6608, 6581, 3001, 491, 3967, 6223, 13, 6652, 6262, 6652, 6368, 2597, 50, 6615, 1981, 2324, 2819, 6477, 6479, 6380, 19, 5, 6635, 2386, 6549]
# [664, 6445, 65, 6361, 1945, 26, 6471, 6001, 15, 701, 6601, 297, 1, 72, 6619, 77, 4370, 2036, 6482, 6623, 6637, 6548, 6220, 37, 6637, 6593, 6540, 6652, 6633, 6566, 6079, 6627, 6646, 5102, 6652, 6481, 5290, 408, 21, 3, 387, 6637, 6609, 6639, 6440, 2578, 1176, 3400, 6438, 153, 18, 6630, 6460, 6426, 0, 1386, 6363, 51, 6301, 6358, 258, 6639, 25, 6562, 6604, 6582, 3353, 558, 4148, 6296, 15, 6652, 6303, 6652, 6304, 6090, 13, 6616, 1204, 3224, 3668, 6462, 6479, 6363, 13, 7, 6635, 2924, 6549]
compare_recommendation_ranks(gt_ranks_direct_mi, gt_ranks_mi_cosine_role, tolerance=15)
direct_better_than_euclid, euclid_better_than_direct, same_direct_euclid = compare_recommendation_ranks(gt_ranks_direct_mi, gt_ranks_mi_euclid_role, tolerance=15)
direct_better_than_manhat, manhat_better_than_direct, same_direct_manhat = compare_recommendation_ranks(gt_ranks_direct_mi, gt_ranks_mi_manhat_role, tolerance=15)

## square dampened
direct_better_than_cosine_sq_damp, cosine_sq_damp_better_than_direct, same_direct_cosine_sq_damp = compare_recommendation_ranks(gt_ranks_direct_mi, gt_ranks_mi_cosine_role_sq_damp, tolerance=15)
direct_better_than_euclid_sq_damp, euclid_sq_damp_better_than_direct, same_direct_euclid_sq_damp = compare_recommendation_ranks(gt_ranks_direct_mi, gt_ranks_mi_euclid_role_sq_damp, tolerance=15)
direct_better_than_manhat_sq_damp, manhat_sq_damp_better_than_direct, same_direct_manhat_sq_damp = compare_recommendation_ranks(gt_ranks_direct_mi, gt_ranks_mi_manhat_role_sq_damp, tolerance=15)

# minimax normalized
direct_better_than_cosine_minimax, cosine_minimax_better_than_direct, same_direct_cosine_minimax = compare_recommendation_ranks(gt_ranks_direct_mi, gt_ranks_mi_cosine_role_minimax, tolerance=15)
direct_better_than_euclid_minimax, euclid_minimax_better_than_direct, same_direct_euclid_minimax = compare_recommendation_ranks(gt_ranks_direct_mi, gt_ranks_mi_euclid_role_minimax, tolerance=15)
direct_better_than_manhat_minimax, manhat_minimax_better_than_direct, same_direct_manhat_minimax = compare_recommendation_ranks(gt_ranks_direct_mi, gt_ranks_mi_manhat_role_minimax, tolerance=15)

print("method to compare to dircet ranks || nr times direct better || nr times other method better || nr times roughly equal")
print(f"cosine || {len(direct_better_than_cosine)} || {len(cosine_better_than_direct)} || {len(same_direct_cosine)}")
print(f"cosine_sq_damp || {len(direct_better_than_cosine_sq_damp)} || {len(cosine_sq_damp_better_than_direct)} || {len(same_direct_cosine_sq_damp)}")
print(f"cosine_minimax || {len(direct_better_than_cosine_minimax)} || {len(cosine_minimax_better_than_direct)} || {len(same_direct_cosine_minimax)}")
print(f"euclid || {len(direct_better_than_euclid)} || {len(euclid_better_than_direct)} || {len(same_direct_euclid)}")
print(f"euclid_sq_damp || {len(direct_better_than_euclid_sq_damp)} || {len(euclid_sq_damp_better_than_direct)} || {len(same_direct_euclid_sq_damp)}")
print(f"euclid_minimax || {len(direct_better_than_euclid_minimax)} || {len(euclid_minimax_better_than_direct)} || {len(same_direct_euclid_minimax)}")
print(f"manhatten || {len(direct_better_than_manhat)} || {len(manhat_better_than_direct)} || {len(same_direct_manhat)}")
print(f"manhatten_sq_damp || {len(direct_better_than_manhat_sq_damp)} || {len(manhat_sq_damp_better_than_direct)} || {len(same_direct_manhat_sq_damp)}")
print(f"manhatten_minimax || {len(direct_better_than_manhat_minimax)} || {len(manhat_minimax_better_than_direct)} || {len(same_direct_manhat_minimax)}")
# Out:
# method to compare to dircet ranks || nr times direct better || nr times other method better || nr times roughly equal
# cosine || 60 || 25 || 0
# cosine_sq_damp || 57 || 27 || 1
# cosine_minimax || 60 || 25 || 0
# euclid || 55 || 29 || 1
# euclid_sq_damp || 58 || 25 || 2
# euclid_minimax || 55 || 29 || 1
# manhatten || 57 || 26 || 2
# manhatten_sq_damp || 61 || 23 || 1
# manhatten_minimax || 57 || 26 || 2

# %%
rank_differences_direct_cosine = []
for direct_rank, role_rank in zip(gt_ranks_direct_mi, gt_ranks_mi_cosine_role):
    rank_differences_direct_cosine.append(direct_rank - role_rank)
print(rank_differences_direct_cosine)
print(sum(rank_differences_direct_cosine) / len(rank_differences_direct_cosine))

rank_differences_direct_euclid_minimax = []
for direct_rank, role_rank in zip(gt_ranks_direct_mi, gt_ranks_mi_euclid_role_minimax):
    rank_differences_direct_euclid_minimax.append(direct_rank - role_rank)
print(rank_differences_direct_euclid_minimax)
print(sum(rank_differences_direct_euclid_minimax) / len(rank_differences_direct_euclid_minimax))

rank_differences_direct_manhat_minimax = []
for direct_rank, role_rank in zip(gt_ranks_direct_mi, gt_ranks_mi_manhat_role_minimax):
    rank_differences_direct_manhat_minimax.append(direct_rank - role_rank)
print(rank_differences_direct_manhat_minimax)
print(sum(rank_differences_direct_manhat_minimax) / len(rank_differences_direct_manhat_minimax))

# average rank is worse for euclid than for cosine though
# Out:
# [111, -2575, 4254, -4797, 1836, -2673, -4627, -2452, -148, 2282, 567, 163, -646, -313, -4976, -2250, 2047, -1743, -3996, -366, 518, -130, -5257, 589, -3142, -1311, -116, -5780, 572, -5729, 133, -170, 1443, -4691, -3404, -4745, -4527, -3144, 982, -505, -545, -2127, -4227, -2311, -628, 1633, -3797, 982, -5528, -646, -26, -5020, 1409, -3787, 273, -3139, -4106, 200, -5047, -3303, -4388, -2344, 652, -5476, 3718, -3832, 2345, -138, -4304, -4797, -164, -4996, 1036, -6630, 4277, -3822, -742, -1967, -5530, -2941, -1076, 65, -1104, -3435, 152]
# -1692.9058823529413
# [-118, -6436, 4225, -6198, -325, 24, -6484, 629, 0, 2127, 1055, -167, 137, 785, -6603, 295, -1444, 883, -116, -6573, -5430, 1496, -6239, 1287, -6633, -6525, -5502, -5780, -5891, -6525, 154, 137, -5064, -2138, -3404, -6042, -5094, -316, 1342, 94, -293, -6630, -5769, 530, -3316, 1885, -3143, -1928, -6437, -112, 36, -5845, 384, -4489, 358, -270, -2500, 187, -2446, -6324, 830, -5978, 804, -6468, -1083, -6517, 1591, 1742, -4049, -6056, 57, -4996, -5233, -6630, 5849, -1190, 936, -6288, -2492, -2357, -857, -48, -6444, -4984, 167]
# -2308.1529411764704
# [-612, -6429, 4246, -6205, 436, 35, -6492, 910, -32, 1670, 1005, -175, 142, 820, -6608, 373, -1343, 2032, -827, -6581, -5433, -4914, -6228, 1321, -6639, -6526, -5517, -5780, -5889, -6519, -1480, 85, -5064, -4970, -3404, -6031, -4978, -294, 1327, 99, -77, -6633, -494, -6076, -3333, 1693, -791, -1991, -6386, 2, -17, -5847, -4798, -4470, 358, 716, -5843, 205, -6175, -6226, 789, -5980, 803, -6474, -1068, -6527, 1253, 1713, -4348, -6162, 54, -4996, -5295, -6630, 5784, -2426, 987, -6303, -1936, -2676, -1865, -9, -6440, -4969, 164]
# -2578.929411764706

# %% [markdown]
# ### get hits@15

# %%
hits_at_15_direct = get_gt_hits_at_k(15, gt_ranks_direct_mi)
hits_at_15_cosine = get_gt_hits_at_k(15, gt_ranks_mi_cosine_role)
hits_at_15_euclid = get_gt_hits_at_k(15, gt_ranks_mi_euclid_role)
hits_at_15_manhat = get_gt_hits_at_k(15, gt_ranks_mi_manhat_role)
hits_at_15_cos_sq_damp = get_gt_hits_at_k(15, gt_ranks_mi_cosine_role_sq_damp)
hits_at_15_cos_minimax = get_gt_hits_at_k(15, gt_ranks_mi_cosine_role_minimax)
hits_at_15_euclid_sq_damp = get_gt_hits_at_k(15, gt_ranks_mi_euclid_role_sq_damp)
hits_at_15_euclid_minimax = get_gt_hits_at_k(15, gt_ranks_mi_euclid_role_minimax)
hits_at_15_manhat_sq_damp = get_gt_hits_at_k(15, gt_ranks_mi_manhat_role_sq_damp)
hits_at_15_manhat_minimax = get_gt_hits_at_k(15, gt_ranks_mi_manhat_role_minimax)

print(hits_at_15_direct)
print("===")
print(hits_at_15_cosine)
print(hits_at_15_cos_sq_damp)
print(hits_at_15_cos_minimax)
print("===")
print(hits_at_15_euclid)
print(hits_at_15_euclid_sq_damp)
print(hits_at_15_euclid_minimax)
print("===")
print(hits_at_15_manhat)
print(hits_at_15_manhat_sq_damp)
print(hits_at_15_manhat_minimax)
# Out:
# [1, 6, 8, 22, 24, 41, 42, 48]
# ===
# [9, 72]
# []
# [9, 72]
# ===
# [8, 12, 38, 39, 50, 54, 62, 70, 84, 85]
# [8, 12, 39, 50, 54, 70, 85]
# [8, 12, 38, 39, 50, 54, 62, 70, 84, 85]
# ===
# [12, 39, 54, 62, 70, 76, 84, 85]
# [8, 12, 39, 54, 70, 76, 84, 85]
# [12, 39, 54, 62, 70, 76, 84, 85]

# %%
# safe all the things
all_recommendations = {
    "direct_source_mutual_info_recommendations": direct_source_mutual_info_recommendations,
    "cosine_similarity_role_recommendations": cosine_similarity_role_recommendations,
    "euclidean_similarity_role_recommendations": euclidean_similarity_role_recommendations,
    "manhatten_similarity_role_recommendations": manhatten_similarity_role_recommendations,
    "cosine_similarity_role_recommendations_sq_damp": cosine_similarity_role_recommendations_sq_damp,
    "euclidean_similarity_role_recommendations_sq_damp": euclidean_similarity_role_recommendations_sq_damp,
    "manhatten_similarity_role_recommendations_sq_damp": manhatten_similarity_role_recommendations_sq_damp,
    "cosine_similarity_role_recommendations_minimax": cosine_similarity_role_recommendations_minimax,
    "euclidean_similarity_role_recommendations_minimax": euclidean_similarity_role_recommendations_minimax,
    "manhatten_similarity_role_recommendations_minimax": manhatten_similarity_role_recommendations_minimax
}
all_recommendations_path = os.path.abspath("./outputs/eval_all_alt_recommendations_every_1th.pkl")
with open(all_recommendations_path, "wb") as file:
    pickle.dump(all_recommendations, file)

# %%
# make some df to get a nice view over recommendations

short_col_names = {
    "direct_source_mutual_info_recommendations": "direct",
    "cosine_similarity_role_recommendations": "cosine",
    "euclidean_similarity_role_recommendations": "euclidean",
    "manhatten_similarity_role_recommendations": "manhatten",
    "cosine_similarity_role_recommendations_sq_damp": "cosine_sq_damp",
    "euclidean_similarity_role_recommendations_sq_damp": "euclidean_sq_damp",
    "manhatten_similarity_role_recommendations_sq_damp": "manhatten_sq_damp",
    "cosine_similarity_role_recommendations_minimax": "cosine_minimax",
    "euclidean_similarity_role_recommendations_minimax": "euclidean_minimax",
    "manhatten_similarity_role_recommendations_minimax": "manhatten_minimax"
}

recipe_id = recipe_ids[6]

transposed_data = []
column_names = []
for recommendation_type, recommendations in list(all_recommendations.items()):
    # if recommendation_type == "direct_source_mutual_info_recommendations":
    #     continue
    if recommendation_type == "direct_source_mutual_info_recommendations":
        data = list(recommendations[recipe_id].keys())
    else:
        data = [rec[0] for rec in recommendations[recipe_id]]
        
    transposed_data.append(data)
    column_names.append(short_col_names[recommendation_type])
    
all_recipe_recs_df = pd.DataFrame(data=transposed_data).T
all_recipe_recs_df.columns = column_names

recipe = getRecipeFromComments(recipe_id, extended_recipes)
print(f"recipe ingredients {recipe['ingredients']}")
print(f"substitutions: {recipe['subs']}")
print(all_recipe_recs_df.head(15))
# Out:
# recipe ingredients [['brown_sugar'], ['powdered_sugar'], ['vanilla_extract', 'butterscotch_extract'], ['low_fat_cream_cheese', 'reduced_fat_cream_cheese'], ['toffee_piece', 'toffee_pieces'], ['pineapple_juice'], ['red_delicious_apple', 'red_delicious_apples'], ['granny_smith_apple', 'granny_smith_apples']]
# substitutions: [('low_fat_cream_cheese', 'neufchatel_cheese'), ('pineapple_juice', 'orange_juice')]
#                             direct                                 cosine  \
# 0                  pineapple_chunk                        pineapple_juice
# 1                              ice                                 raisin
# 2                        soy_sauce                                 peanut
# 3                        grenadine                             applesauce
# 4                      coconut_rum                                    oat
# 5                        pineapple                             rolled_oat
# 6                  pineapple_slice  ghirardelli_semi_sweet_chocolate_chip
# 7                 pineapple_tidbit                              hemp_seed
# 8                     blue_curacao                         rolo_chocolate
# 9   carbonated_lemon_lime_beverage                         vanilla_yogurt
# 10                    orange_juice              canned_solid_pack_pumpkin
# 11                       white_rum                         chocolate_chip
# 12                      cornstarch                    mashed_sweet_potato
# 13            midori_melon_liqueur                             wheat_bran
# 14                 cranberry_juice                                   seed
#
#                  euclidean               manhatten  \
# 0          pineapple_juice         pineapple_juice
# 1      mashed_sweet_potato     mashed_sweet_potato
# 2              butter_bean             butter_bean
# 3               baked_bean              tart_apple
# 4               tart_apple              baked_bean
# 5            cooking_apple           cooking_apple
# 6          powdered_ginger                 bourbon
# 7   country_style_pork_rib         powdered_ginger
# 8                  bourbon                  peanut
# 9          all_bran_cereal   quick_cooking_oatmeal
# 10            natural_bran         red_curry_paste
# 11                crabmeat          vanilla_yogurt
# 12              white_rice  country_style_pork_rib
# 13   quick_cooking_oatmeal         all_bran_cereal
# 14            miracle_whip            natural_bran
#
#                            cosine_sq_damp     euclidean_sq_damp  \
# 0                         pineapple_juice       pineapple_juice
# 1                                  raisin   mashed_sweet_potato
# 2                                     oat           butter_bean
# 3                          chocolate_chip          sweet_potato
# 4   ghirardelli_semi_sweet_chocolate_chip       powdered_ginger
# 5                               hemp_seed            tart_apple
# 6                         red_curry_paste  low_sodium_soy_sauce
# 7                              applesauce            baked_bean
# 8                          rolo_chocolate        frozen_spinach
# 9                              wheat_bran       velveeta_cheese
# 10                          pork_sparerib   mini_chocolate_chip
# 11              canned_solid_pack_pumpkin                ginger
# 12                    bottled_chili_sauce              pine_nut
# 13             garlic_and_red_chile_paste         fresh_spinach
# 14                   mexican_chili_powder           heavy_cream
#
#        manhatten_sq_damp                         cosine_minimax  \
# 0        pineapple_juice                        pineapple_juice
# 1    mashed_sweet_potato                                 raisin
# 2            butter_bean                                 peanut
# 3             tart_apple                             applesauce
# 4        powdered_ginger                                    oat
# 5             baked_bean                             rolled_oat
# 6           sweet_potato  ghirardelli_semi_sweet_chocolate_chip
# 7         frozen_spinach                              hemp_seed
# 8   low_sodium_soy_sauce                         rolo_chocolate
# 9                 ginger                         vanilla_yogurt
# 10         cooking_apple              canned_solid_pack_pumpkin
# 11       velveeta_cheese                         chocolate_chip
# 12       all_bran_cereal                    mashed_sweet_potato
# 13            white_rice                             wheat_bran
# 14   mini_chocolate_chip                                   seed
#
#          euclidean_minimax       manhatten_minimax
# 0          pineapple_juice         pineapple_juice
# 1      mashed_sweet_potato     mashed_sweet_potato
# 2              butter_bean             butter_bean
# 3               baked_bean              tart_apple
# 4               tart_apple              baked_bean
# 5            cooking_apple           cooking_apple
# 6          powdered_ginger                 bourbon
# 7   country_style_pork_rib         powdered_ginger
# 8                  bourbon                  peanut
# 9          all_bran_cereal   quick_cooking_oatmeal
# 10            natural_bran         red_curry_paste
# 11                crabmeat          vanilla_yogurt
# 12              white_rice  country_style_pork_rib
# 13   quick_cooking_oatmeal         all_bran_cereal
# 14            miracle_whip            natural_bran

# %%
# num_cosine_better = 0
# num_euclid_better = 0
# num_manhat_better = 0
# for i in range(len(gt_ranks_direct_mi)):
#     if (gt_ranks_direct_mi[i] > gt_ranks_mi_cosine_role[i]):
#         num_cosine_better += 1
#     if (gt_ranks_direct_mi[i] > gt_ranks_mi_euclid_role[i]):
#         num_euclid_better += 1
#     if (gt_ranks_direct_mi[i] > gt_ranks_mi_manhat_role[i]):
#         num_manhat_better += 1
        
# print(f"total predictions: {len(gt_ranks_direct_mi)}\nnum cosine better: {num_cosine_better}\nnum euclid better: {num_euclid_better}\nnum manhat better: {num_manhat_better}")
# Out:
# total predictions: 10
# num cosine better: 6
# num euclid better: 7
# num manhat better: 4

# %% [markdown]
# ### Check how frequent the gt sources of the recipes and the other recipe ingredients appear in the dataset

# %%
source_ingredients = source_ingredients # all source ingredients that were used to find recommendations
used_recipes = []

for recipe_id in recipe_ids:
    used_recipes.append(getRecipeFromComments(recipe_id, extended_recipes))
# Out:
#   Cell In[36], line 4
#     for recipe_id in recipe_ids:
#                                 ^
# SyntaxError: incomplete input

# %%
indices_for_rank_worse_than_4k = [i for i, value in enumerate(gt_ranks_mi_euclid_role) if value > 4000]
indices_for_rank_worse_than_4k

recipe_ids_for_rank_worse_than_4k = [recipe_ids[i] for i in indices_for_rank_worse_than_4k]
recipe_ids_for_rank_worse_than_4k

for recipe_id in recipe_ids_for_rank_worse_than_4k:
    print(f"recipe id: {recipe_id} source ingredient frequency: {source_ingredients[recipe_id]}: {len(recipes_per_ingredient[source_ingredients[recipe_id]])}")
    recipe_ingredients = getRecipeFromComments(recipe_id, extended_recipes)["ingredients"]
    ingredient_frequencies = {}
    for recipe_ingredient in recipe_ingredients:
        for ingredient_variant in recipe_ingredient:
            if ingredient_variant in list(recipes_per_ingredient.keys()):
                ingredient_frequencies[ingredient_variant] = len(recipes_per_ingredient[ingredient_variant])
                break
    print(f"Recipe ingredient frequencies: {ingredient_frequencies}")
    
    print("---")
# Out:
# recipe id: 0609ee46a6 source ingredient frequency: cold_water: 476
# Recipe ingredient frequencies: {'bisquick_baking_mix': 54, 'cold_water': 476, 'sharp_cheddar_cheese': 512, 'butter': 11274, 'dry_parsley_flake': 964, 'garlic_powder': 2392, 'italian_seasoning': 458}
# ---
# recipe id: 11911fb3d0 source ingredient frequency: maraschino_cherry: 132
# Recipe ingredient frequencies: {'all_purpose_flour': 4061, 'baking_soda': 4119, 'butter': 11274, 'white_sugar': 806, 'brown_sugar': 4141, 'instant_pistachio_pudding_mix': 15, 'egg': 11024, 'almond_extract': 425, 'green_food_coloring': 48, 'semisweet_chocolate_chip': 1, 'maraschino_cherry': 132, 'pistachio': 57}
# ---
# recipe id: 225750a2c3 source ingredient frequency: pineapple_juice: 209
# Recipe ingredient frequencies: {'brown_sugar': 4141, 'powdered_sugar': 930, 'vanilla_extract': 2135, 'low_fat_cream_cheese': 66, 'toffee_piece': 27, 'pineapple_juice': 209, 'red_delicious_apple': 25, 'granny_smith_apple': 198}
# ---
# recipe id: 5209b68235 source ingredient frequency: heavy_cream: 1145
# Recipe ingredient frequencies: {'cocoa_powder': 299, 'mineral_water': 8, 'granulated_sugar': 1271, 'corn_syrup': 134, 'heavy_cream': 1145, 'semisweet_chocolate': 127, 'cake': 9, 'fruit': 33}
# ---
# recipe id: 5d12f1d30d source ingredient frequency: dried_marjoram: 120
# Recipe ingredient frequencies: {'french_style_green_bean': 30, 'butter': 11274, 'lemon_zest': 320, 'dried_marjoram': 120, 'salt': 18957, 'lemon_slice': 75}
# ---
# recipe id: 6f480cc7e0 source ingredient frequency: beer: 214
# Recipe ingredient frequencies: {'corned_beef_brisket': 17, 'potato': 1831, 'onion': 11088, 'carrot': 3317, 'bay_leaf': 1266, 'beer': 214, 'cabbage': 481}
# ---
# recipe id: 752cc1e053 source ingredient frequency: half_and_half: 508
# Recipe ingredient frequencies: {'butter': 11274, 'garlic_clove': 8942, 'onion': 11088, 'celery': 2451, 'flour': 6114, 'clam': 51, 'half_and_half': 508, 'ground_thyme': 43, 'salt': 18957}
# ---
# recipe id: 809625d7f4 source ingredient frequency: maple_syrup: 374
# Recipe ingredient frequencies: {'butter': 11274, 'salt': 18957, 'maple_syrup': 374, 'vanilla': 3182, 'powdered_sugar': 930, 'milk': 5514}
# ---
# recipe id: 8ca6572033 source ingredient frequency: cayenne_pepper: 1385
# Recipe ingredient frequencies: {'lime_juice': 634, 'fresh_tomato': 132, 'bell_pepper': 429, 'red_bell_pepper': 1087, 'sweet_onion': 309, 'jalapeno': 346, 'cilantro': 782, 'vinegar': 679, 'garlic_clove': 8942, 'cayenne_pepper': 1385, 'honey': 1908, 'crushed_red_pepper_flake': 693}
# ---
# recipe id: 92595f3ec0 source ingredient frequency: greek_yogurt: 82
# Recipe ingredient frequencies: {'pita_pocket_bread': 6, 'olive_oil': 6240, 'garlic_powder': 2392, 'greek_yogurt': 82, 'red_onion': 1336, 'fresh_chive': 254, 'chickpea': 280, 'garlic_clove': 8942, 'tahini': 127, 'lemon': 1384, 'salt_&_freshly_ground_black_pepper': 520, 'red_bell_pepper': 1087, 'yellow_bell_pepper': 165, 'plum_tomato': 275, 'kalamata_olive': 191, 'feta_cheese': 492, 'spring_onion': 154}
# ---
# recipe id: 98348cc049 source ingredient frequency: velveeta_cheese: 162
# Recipe ingredient frequencies: {'bacon': 1341, 'potato': 1831, 'chicken_broth': 2031, 'carrot': 3317, 'onion': 11088, 'dry_parsley_flake': 964, 'celery_seed': 229, 'kosher_salt': 1005, 'black_pepper': 2681, 'all_purpose_flour': 4061, 'milk': 5514, 'velveeta_cheese': 162, 'green_onion': 2627}
# ---
# recipe id: 9e22f07aa0 source ingredient frequency: lean_ground_beef: 690
# Recipe ingredient frequencies: {'lean_ground_beef': 690, 'kielbasa': 92, 'whole_tomato': 164, 'frozen_french_cut_green_bean': 5, 'pitted_black_olive': 40, 'red_wine': 298, 'garlic_clove': 8942, 'onion': 11088, 'green_pepper': 1337, 'basil': 593, 'oregano': 961, 'thyme': 681, 'pepper': 4862, 'pasta': 211, 'parmesan_cheese': 3244}
# ---
# recipe id: a424bc3e98 source ingredient frequency: grand_marnier: 55
# Recipe ingredient frequencies: {'gold_tequila': 7, 'grand_marnier': 55, 'cranberry_juice': 57, 'fresh_lime_juice': 405}
# ---
# recipe id: a9f0a51642 source ingredient frequency: unsalted_butter: 1559
# Recipe ingredient frequencies: {'unsalted_butter': 1559, 'sugar': 9198, 'vanilla': 3182, 'egg': 11024, 'milk': 5514, 'crushed_pineapple': 293, 'dried_cranberry': 368, 'pecan': 1221, 'bread': 326}
# ---
# recipe id: bb68e15d81 source ingredient frequency: garlic_salt: 647
# Recipe ingredient frequencies: {'boneless_skinless_chicken_breast': 1199, 'egg_white': 842, 'corn_flake_crumb': 32, 'garlic_salt': 647, 'paprika': 1683, 'black_pepper': 2681, 'parmesan_cheese': 3244}
# ---
# recipe id: c71d3c0855 source ingredient frequency: granulated_sugar: 1271
# Recipe ingredient frequencies: {'sour_cream': 2734, 'mayonnaise': 1714, 'cider_vinegar': 524, 'salt': 18957, 'granulated_sugar': 1271, 'white_pepper': 587, 'green_seedless_grape': 30, 'cashew': 136, 'fresh_cranberry': 112}
# ---
# recipe id: cd29287bb6 source ingredient frequency: cayenne: 384
# Recipe ingredient frequencies: {'balsamic_vinegar': 640, 'fresh_orange_juice': 116, 'fresh_lemon_juice': 953, 'lite_olive_oil': 29, 'fresh_oregano': 153, 'cayenne': 384, 'salt_&_pepper': 429}
# ---
# recipe id: d355503f7a source ingredient frequency: sliced_mushroom: 441
# Recipe ingredient frequencies: {'lean_beef': 19, 'sliced_mushroom': 441, 'onion': 11088, 'green_bell_pepper': 961, 'sliced_ripe_olive': 66, 'tomato_sauce': 1167, 'sugar_twin': 3, 'italian_seasoning': 458, 'refrigerated_buttermilk_biscuit': 31, 'light_cheddar_cheese': 108, 'reduced_fat_mozzarella_cheese': 17}
# ---
# recipe id: f18047ba01 source ingredient frequency: heavy_cream: 1145
# Recipe ingredient frequencies: {'olive_oil': 6240, 'flour': 6114, 'chicken': 417, 'onion': 11088, 'carrot': 3317, 'celery': 2451, 'whole_bay_leaf': 21, 'fresh_thyme': 360, 'turmeric': 425, 'low_sodium_chicken_broth': 394, 'fresh_parsley': 1692, 'baking_powder': 4701, 'cornmeal': 346, 'sugar': 9198, 'kosher_salt': 1005, 'heavy_cream': 1145}
# ---
# recipe id: f6cf2dcf62 source ingredient frequency: oil: 2205
# Recipe ingredient frequencies: {'flour': 6114, 'baking_powder': 4701, 'sugar': 9198, 'salt': 18957, 'oil': 2205, 'egg': 11024, 'orange_juice': 759, 'apple': 803, 'cinnamon': 3068}
# ---
# recipe id: 0ca6dfddba source ingredient frequency: maraschino_cherry: 132
# Recipe ingredient frequencies: {'date': 174, 'pecan': 1221, 'maraschino_cherry': 132, 'semi_sweet_chocolate_chip': 501, 'egg': 11024, 'butter': 11274, 'baking_powder': 4701, 'salt': 18957, 'sugar': 9198, 'flour': 6114}
# ---
# recipe id: 805673ceac source ingredient frequency: cooked_orzo_pasta: 4
# Recipe ingredient frequencies: {'plain_yogurt': 376, 'garlic_clove': 8942, 'of_fresh_mint': 197, 'salt': 18957, 'onion': 11088, 'olive_oil': 6240, 'red_bell_pepper': 1087, 'ground_coriander': 440, 'ground_cumin': 1329, 'chickpea': 280, 'spinach': 248, 'salt_and_pepper': 3234, 'cooked_orzo_pasta': 4}
# ---
# recipe id: d8f4a6e2c5 source ingredient frequency: cinnamon_stick: 279
# Recipe ingredient frequencies: {'brown_sugar': 4141, 'apple_cider_vinegar': 257, 'water': 7849, 'fresh_ginger': 838, 'lemon_zest': 320, 'cinnamon_stick': 279, 'fresh_rhubarb': 16, 'dark_raisin': 35}
# ---
# recipe id: 120a1b2c37 source ingredient frequency: white_vinegar: 443
# Recipe ingredient frequencies: {'cabbage': 481, 'carrot': 3317, 'garlic_clove': 8942, 'onion': 11088, 'fresh_ginger': 838, 'black_pepper': 2681, 'salt': 18957, 'white_vinegar': 443, 'canola_oil': 1036}
# ---
# recipe id: ae683c2a70 source ingredient frequency: evaporated_skim_milk: 41
# Recipe ingredient frequencies: {'sweet_potato': 413, 'banana': 1120, 'evaporated_skim_milk': 41, 'brown_sugar': 4141, 'egg_yolk': 559, 'salt': 18957, 'raisin': 1255, 'sugar': 9198, 'ground_cinnamon': 1473, 'nonstick_cooking_spray': 123}
# ---
# recipe id: e32f4a3a9c source ingredient frequency: hershey's_semi_sweet_chocolate_chip: 2
# Recipe ingredient frequencies: {'all_purpose_flour': 4061, 'sugar': 9198, 'salt': 18957, 'margarine': 1361, 'egg': 11024, 'sweetened_condensed_milk': 286, 'maple_flavoring': 24, 'nut': 549, "hershey's_semi_sweet_chocolate_chip": 2}
# ---
# recipe id: 146270d657 source ingredient frequency: sugar: 9198
# Recipe ingredient frequencies: {'green_bean': 406, 'soy_sauce': 1935, 'water': 7849, 'dry_sherry': 252, 'sugar': 9198, 'cornstarch': 1631, 'red_pepper_powder': 194, 'fresh_ginger': 838, 'fresh_garlic_clove': 282, 'peanut_oil': 328, 'sesame_oil': 624}
# ---
# recipe id: 2dfd43fefc source ingredient frequency: cilantro: 782
# Recipe ingredient frequencies: {'onion': 11088, 'tomato': 2219, 'cilantro': 782, 'garlic': 2097, 'white_distilled_vinegar': 53}
# ---
# recipe id: 47ec587d53 source ingredient frequency: lard: 61
# Recipe ingredient frequencies: {'unbleached_white_flour': 163, 'baking_powder': 4701, 'salt': 18957, 'lard': 61, 'warm_water': 356}
# ---
# recipe id: 99c918e7cb source ingredient frequency: shortening: 683
# Recipe ingredient frequencies: {'shortening': 683, 'flour': 6114, 'sugar': 9198, 'baking_powder': 4701, 'baking_soda': 4119, 'salt': 18957, 'banana': 1120, 'buttermilk': 902, 'egg': 11024}
# ---
# recipe id: b5c4ac9062 source ingredient frequency: fresh_chive: 254
# Recipe ingredient frequencies: {'potato': 1831, 'oil': 2205, 'dry_breadcrumb': 222, 'fresh_chive': 254, 'celery_salt': 173, 'garlic_powder': 2392, 'fresh_rosemary': 292}
# ---
# recipe id: ed9083f4ac source ingredient frequency: walnut: 1501
# Recipe ingredient frequencies: {'chicken_breast': 639, 'cajun_seasoning': 146, 'butter': 11274, 'heavy_cream': 1145, 'lemon_pepper_seasoning': 54, 'salt': 18957, 'black_pepper': 2681, 'garlic_powder': 2392, 'penne_pasta': 181, 'roma_tomato': 195, 'parmesan_cheese': 3244}
# ---
# recipe id: 3078472c6a source ingredient frequency: acorn_squash: 57
# Recipe ingredient frequencies: {'spanish_onion': 58, 'garlic_clove': 8942, 'turmeric': 425, 'curry_powder': 675, 'cumin': 1068, 'red_pepper_flake': 590, 'salt': 18957, 'pepper': 4862, 'cinnamon': 3068, 'ground_nutmeg': 599, 'sweet_potato': 413, 'acorn_squash': 57, 'carrot': 3317, 'vegetable_broth': 366, 'chickpea': 280, 'whole_tomato': 164, 'raisin': 1255}
# ---
# recipe id: b664dd53b6 source ingredient frequency: soy_flour: 27
# Recipe ingredient frequencies: {'soy_flour': 27, 'whole_wheat_flour': 938, 'baking_soda': 4119, 'baking_powder': 4701, 'salt': 18957, 'ground_cinnamon': 1473, 'ground_allspice': 257, 'nutmeg': 1411, 'margarine': 1361, 'winter_squash': 13, 'molasses': 375, 'walnut': 1501, 'sunflower_seed': 202, 'dried_currant': 51}
# ---
# recipe id: 259fe7f1c0 source ingredient frequency: salt: 18957
# Recipe ingredient frequencies: {'zucchini': 1087, 'summer_squash': 46, 'red_bell_pepper': 1087, 'yellow_bell_pepper': 165, 'fresh_asparagus': 68, 'red_onion': 1336, 'extra_virgin_olive_oil': 1338, 'salt': 18957, 'black_pepper': 2681}
# ---
# recipe id: adfcb3b12c source ingredient frequency: white_bread: 184
# Recipe ingredient frequencies: {'mushroom': 999, 'butter': 11274, 'salt': 18957, 'ground_black_pepper': 1256, 'light_cream': 164, 'white_bread': 184}
# ---
# recipe id: c6ff71f531 source ingredient frequency: quince: 2
# Recipe ingredient frequencies: {'chicken': 417, 'onion': 11088, 'butter': 11274, 'quince': 2, 'chicken_soup_base': 12, 'red_pepper': 577, 'coriander': 201, 'ginger': 714, 'turmeric_powder': 63, 'cinnamon': 3068, 'salt': 18957, 'pepper': 4862}
# ---
# recipe id: 90e7e392c6 source ingredient frequency: ghee: 70
# Recipe ingredient frequencies: {'banana': 1120, 'sugar': 9198, 'water': 7849, 'ghee': 70, 'almond': 326, 'cardamom_seed': 19, 'saffron': 80}
# ---
# recipe id: 92a3b71db5 source ingredient frequency: red_cayenne_pepper: 16
# Recipe ingredient frequencies: {'chicken_piece': 92, 'liquid_honey': 58, 'butter': 11274, 'dijon_mustard': 1014, 'curry_powder': 675, 'red_cayenne_pepper': 16}
# ---

# %%
indices_for_rank_better_than_250 = [i for i, value in enumerate(gt_ranks_mi_euclid_role) if value < 250]
indices_for_rank_better_than_250

recipe_ids_for_rank_better_than_250 = [recipe_ids[i] for i in indices_for_rank_better_than_250]
recipe_ids_for_rank_better_than_250

for recipe_id in recipe_ids_for_rank_better_than_250:
    print(f"recipe id: {recipe_id} source ingredient frequency: {source_ingredients[recipe_id]}: {len(recipes_per_ingredient[source_ingredients[recipe_id]])}")
    recipe_ingredients = getRecipeFromComments(recipe_id, extended_recipes)["ingredients"]
    ingredient_frequencies = {}
    for recipe_ingredient in recipe_ingredients:
        for ingredient_variant in recipe_ingredient:
            if ingredient_variant in list(recipes_per_ingredient.keys()):
                ingredient_frequencies[ingredient_variant] = len(recipes_per_ingredient[ingredient_variant])
                break
    print(f"Recipe ingredient frequencies: {ingredient_frequencies}")
    
    print("---")
# Out:
# recipe id: 0bdfe50be7 source ingredient frequency: feta_cheese: 492
# Recipe ingredient frequencies: {'vegetable_oil': 3413, 'warm_water': 356, 'salt': 18957, 'flour': 6114, 'egg_yolk': 559, 'parmesan_cheese': 3244, 'eggplant': 252, 'feta_cheese': 492, 'salt_and_pepper': 3234}
# ---
# recipe id: 1cbef47545 source ingredient frequency: sugar: 9198
# Recipe ingredient frequencies: {'low_fat_graham_cracker': 2, 'smart_balance_butter_spread': 10, 'water': 7849, 'cold_water': 476, 'unflavored_gelatin': 50, 'sugar': 9198, 'salt': 18957, 'all_purpose_flour': 4061, 'egg_yolk': 559, 'nonfat_milk': 192, 'vanilla_extract': 2135, 'banana_liqueur': 9, 'dark_rum': 107, 'banana': 1120}
# ---
# recipe id: 2e4b665146 source ingredient frequency: cherry_tomato: 279
# Recipe ingredient frequencies: {'green_bean': 406, 'feta_cheese': 492, 'olive_oil': 6240, 'garlic_clove': 8942, 'kalamata_olive': 191, 'cherry_tomato': 279, 'fresh_lemon_juice': 953, 'fresh_oregano': 153, 'salt_and_pepper': 3234}
# ---
# recipe id: 3448ed4a58 source ingredient frequency: water: 7849
# Recipe ingredient frequencies: {'brown_rice': 169, 'tofu': 57, 'water': 7849, 'lentil': 106, 'vegetable': 69, 'garlic_powder': 2392, 'basil': 593, 'oregano': 961, 'parsley': 1497, 'herbes_de_provence': 42}
# ---
# recipe id: 3a58d7c63a source ingredient frequency: maraschino_cherry_juice: 9
# Recipe ingredient frequencies: {'orange_juice': 759, 'triple_sec': 58, 'tequila': 96, 'maraschino_cherry_juice': 9, 'maraschino_cherry': 132}
# ---
# recipe id: 45b868c768 source ingredient frequency: milk: 5514
# Recipe ingredient frequencies: {'flour': 6114, 'baking_powder': 4701, 'salt': 18957, 'butter': 11274, 'sugar': 9198, 'egg': 11024, 'vanilla': 3182, 'milk': 5514, 'apple': 803, 'ground_cinnamon': 1473}
# ---
# recipe id: 4bccb024e3 source ingredient frequency: raisin: 1255
# Recipe ingredient frequencies: {'margarine': 1361, 'natural_style_peanut_butter': 49, 'honey': 1908, 'vanilla': 3182, 'salt': 18957, 'chocolate_protein_powder': 9, 'rolled_oat': 467, 'raisin': 1255}
# ---
# recipe id: 57a13aaff9 source ingredient frequency: vanilla: 3182
# Recipe ingredient frequencies: {'cornstarch': 1631, 'granulated_sugar': 1271, 'salt': 18957, 'milk': 5514, 'vanilla': 3182, 'unsweetened_chocolate': 82}
# ---
# recipe id: 7af2705789 source ingredient frequency: water: 7849
# Recipe ingredient frequencies: {'lean_stewing_beef': 26, 'seasoned_flour': 12, 'extra_virgin_olive_oil': 1338, 'dry_mustard': 547, 'spanish_onion': 58, 'bulb_of_garlic': 8, 'port_wine': 20, 'baby_carrot': 168, 'rutabaga': 33, 'celery': 2451, 'mushroom': 999, 'cayenne_pepper': 1385, 'dried_thyme': 797, 'worcestershire_sauce': 1597, 'creamed_horseradish': 3, 'salt': 18957, 'water': 7849, 'white_potato': 56}
# ---
# recipe id: 86af4e0bf0 source ingredient frequency: hamburger_bun: 132
# Recipe ingredient frequencies: {'ground_beef': 1619, 'onion': 11088, 'celery_&_leaf': 23, 'green_pepper': 1337, 'crushed_tomato': 271, 'ketchup': 834, 'brown_sugar': 4141, 'vinegar': 679, 'worcestershire_sauce': 1597, 'steak_sauce': 44, 'garlic_salt': 647, 'ground_mustard': 81, 'paprika': 1683, 'hamburger_bun': 132}
# ---
# recipe id: af8d90f7cf source ingredient frequency: brown_rice_flour: 43
# Recipe ingredient frequencies: {'brown_rice_flour': 43, 'cornstarch': 1631, 'powdered_milk': 107, 'xanthan_gum': 108, 'salt': 18957, 'warm_water': 356, 'active_dry_yeast': 268, 'oil': 2205, 'egg': 11024}
# ---
# recipe id: b55d387a08 source ingredient frequency: walnut: 1501
# Recipe ingredient frequencies: {'peaches_in_light_syrup': 4, 'yellow_cake_mix': 174, 'butter': 11274, 'brown_sugar': 4141, 'walnut': 1501}
# ---
# recipe id: df06c0a5b5 source ingredient frequency: vanilla: 3182
# Recipe ingredient frequencies: {'sweetened_condensed_milk': 286, 'coconut': 275, 'vanilla': 3182}
# ---
# recipe id: e546491f8c source ingredient frequency: milk: 5514
# Recipe ingredient frequencies: {'rye_flour': 41, 'salt': 18957, 'baking_powder': 4701, 'shortening': 683, 'egg': 11024, 'milk': 5514}
# ---
# recipe id: fccc44c4c7 source ingredient frequency: olive_oil: 6240
# Recipe ingredient frequencies: {'medium_shrimp': 126, 'garlic_clove': 8942, 'chili_flake': 42, 'olive_oil': 6240, 'salt': 18957}
# ---
# recipe id: 9db18df7d7 source ingredient frequency: sugar: 9198
# Recipe ingredient frequencies: {'sugar': 9198, 'bell_pepper': 429, 'wesson_oil': 7, 'white_onion': 321, 'green_onion': 2627, 'soy_sauce': 1935}
# ---
# recipe id: ba28653bd5 source ingredient frequency: nutmeg: 1411
# Recipe ingredient frequencies: {'flour': 6114, 'baking_powder': 4701, 'baking_soda': 4119, 'salt': 18957, 'nutmeg': 1411, 'cinnamon': 3068, 'egg': 11024, 'oil': 2205, 'vanilla': 3182, 'light_brown_sugar': 590, 'zucchini': 1087, 'dried_cranberry': 368, 'date': 174, 'unsalted_sunflower_seed': 15}
# ---
# recipe id: 2cf7d13f95 source ingredient frequency: water: 7849
# Recipe ingredient frequencies: {'stewing_beef': 56, 'carrot': 3317, 'potato': 1831, 'frozen_white_corn': 240, 'onion': 11088, 'gravy_mix': 2, 'lipton_onion_soup_mix': 37, 'water': 7849}
# ---
# recipe id: 7c27430af8 source ingredient frequency: water: 7849
# Recipe ingredient frequencies: {'all_purpose_flour': 4061, 'black_pepper': 2681, 'salt': 18957, 'canola_oil': 1036, 'round_steak': 74, 'garlic': 2097, 'celery': 2451, 'onion': 11088, 'dry_parsley_flake': 964, 'canned_tomato': 98, 'water': 7849, 'steak_sauce': 44}
# ---
# recipe id: cac4a31b22 source ingredient frequency: chocolate_wafer: 9
# Recipe ingredient frequencies: {'vanilla_wafer': 51, 'chocolate_wafer': 9, 'cream_cheese_frosting': 20, 'food_coloring': 44, 'shredded_coconut': 133}
# ---
# recipe id: fb954a5263 source ingredient frequency: light_cream: 164
# Recipe ingredient frequencies: {'leek': 337, 'butter': 11274, 'potato': 1831, 'carrot': 3317, 'light_cream': 164}
# ---
# recipe id: d14a380798 source ingredient frequency: walnut: 1501
# Recipe ingredient frequencies: {'green_bean': 406, 'unsalted_butter': 1559, 'walnut': 1501, 'parmesan_cheese': 3244}
# ---
# recipe id: 424b4799cc source ingredient frequency: fat_free_buttermilk: 11
# Recipe ingredient frequencies: {'whole_wheat_flour': 938, 'cream_of_tartar': 175, 'baking_soda': 4119, 'salt': 18957, 'splenda_sugar_substitute': 184, 'fat_free_buttermilk': 11, 'plain_fat_free_yogurt': 61, 'vanilla_extract': 2135, 'butter_bud': 5}
# ---
# recipe id: 0b82701031 source ingredient frequency: ground_beef: 1619
# Recipe ingredient frequencies: {'ground_beef': 1619, 'breadcrumb': 558, 'water': 7849, 'fresh_ground_pepper': 672, 'egg': 11024, 'lipton_onion_soup_mix': 37, 'roll': 34}
# ---
# recipe id: 92d90c444a source ingredient frequency: lemon_juice: 2597
# Recipe ingredient frequencies: {'avocado': 520, 'salsa': 586, 'onion': 11088, 'salt': 18957, 'pepper': 4862, 'lemon_juice': 2597}
# ---
# recipe id: e29668d4bb source ingredient frequency: red_wine_vinegar: 634
# Recipe ingredient frequencies: {'lemon_juice': 2597, 'red_wine_vinegar': 634, 'fresh_basil_leaf': 241, 'dijon_mustard': 1014, 'olive_oil': 6240, 'salt': 18957, 'pepper': 4862}
# ---
# recipe id: 08920ce53f source ingredient frequency: walnut: 1501
# Recipe ingredient frequencies: {'butter': 11274, 'brown_sugar': 4141, 'vanilla': 3182, 'all_purpose_flour': 4061, 'walnut': 1501, 'semi_sweet_chocolate_chip': 501}
# ---

# %% [markdown]
# ## Some more dataset verifications

# %%
# ingredients = get_graph_nodes(GRAPH_NODES_PATH)
ingredients = list(mutual_info_dict.keys())

forgotten_ingredients = []
not_forgotten_ingredients = []
for recipe in extended_recipes:
    for ingredient_list in recipe["ingredients"]:
        ingredient = ingredient_list[0]
        # if ingredient in ingredients:
        #     print("y")
        # else:
        #     print("n")
        if (ingredient not in ingredients) and (ingredient not in forgotten_ingredients):
            forgotten_ingredients.append(ingredient)
        if (ingredient in ingredients) and (ingredient not in not_forgotten_ingredients):
            not_forgotten_ingredients.append(ingredient)
            
print(f"forgotten ingredients: {forgotten_ingredients}")
# Out:
# forgotten ingredients: []

# %%
forgotten_inner_ingredients = []
all_ingredients = get_graph_nodes(GRAPH_NODES_PATH)
for ingredient in all_ingredients:
    if ingredient not in list(list(mutual_info_dict.items())[0][1].keys()):
        forgotten_inner_ingredients.append(ingredient)

# a = "dried_parsley" in list(list(mutual_info_dict.items())[0][1].keys())
# # print(list(list(mutual_info_dict.items())[0][1].keys()))
# print(a)
print(forgotten_inner_ingredients)
print("dried_parsley" in all_ingredients)
# Out:
# []
# False

# %% [markdown]
# ### some of the source ingredients are not found in the nodes list ?

# %%
all_gt_sources = [recipe["subs"][0] for recipe in extended_recipes]
# print(all_gt_sources)
# print("dried_parsley" in all_gt_sources)

gt_sources_which_are_not_nodes = []
for gt_source in all_gt_sources:
    if gt_source not in all_ingredients:
        gt_sources_which_are_not_nodes.append(gt_source)
        
print(gt_sources_which_are_not_nodes)
print(len(gt_sources_which_are_not_nodes))
print(len(all_gt_sources))
# Out:
# ['frozen_chopped_broccoli', 'chicken_broth_with_roasted_garlic', 'panini_bread', 'instant_chocolate_fudge_pudding', 'vegetable_salt', 'cream_filled_chocolate_sandwich_cookies', 'lemon_infused_olive_oil', 'dried_parsley', 'artificial_sweetener', 'kaiser_rolls', 'turkey_bacon', 'fat_free_sugar_free_instant_chocolate_pudding_mix', 'vanilla_butternut_flavoring', 'butterscotch_extract', 'dried_rosemary', 'dried_parsley', 'full_cream_milk', 'whiskey', 'sugar_free_fat_free_butterscotch_pudding', 'ground_red_pepper', 'frozen_chopped_broccoli', 'mrs._dash_tomato_basil_garlic_seasoning', 'bread_
ed_red_pepper', 'chives', 'dried_parsley', 'gluten_free_chicken_stock', 'dried_rosemary', 'graham_cracker_crumbs', 'lemon_mayonnaise', 'dry_crushed_red_pepper', 'cream_of_chicken_soup_mix', 'chocolate_chip_ice_cream', 'dry_crushed_red_pepper', "mrs_dash's_extra_spicy_seasoning", 'diced_tomatoes_with_sweet_onions', 'cooked_rigatoni_pasta', 'fresh_mushrooms', 'lemon_mayonnaise', 'dried_parsley', 'lemon_infused_olive_oil', 'coleslaw_mix', 'salt_free_garlic_powder', 'vegetable_salt', 'fresh_mushrooms', 'salt_free_garlic_powder', 'salt_free_garlic_powder', 'vegetable_salt', 'dry_crushed_red_pepper', 'chicke ...
# 1261
# 70520

# %%
# get some meat
ingo_ids = []
for recipe_id, recipe in recipes_extended_dict.items():
    if recipe["subs"][0] == "ground_beef":
        ingo_ids.append(recipe_id)
    
print(ingo_ids)
# Out:
# ['00b2b2edbd', '0177c1bb48', '0271aa0503', '036bdeca88', '04911b2bed', '07122400ca', '08773418c4', '08c66bdc32', '0a8fac8be4', '0c1ae64700', '0e03cf19a1', '0e2c46410e', '0f4dd0863e', '11098cc0d3', '1181fe4911', '124b93847e', '14532143af', '18928fe2cd', '18c95e9bfc', '191c232acf', '19222783ad', '1a7d728eeb', '1b4d3440a8', '1d1fadfcf2', '1fef38437a', '22d85701e0', '24ebf71910', '2606a45b70', '27e5c0162f', '27f3cd87b0', '28cf00b64a', '28dca771e9', '2b33877066', '2bef80c126', '2c3c533343', '2c65cf040b', '2da5b27ec7', '2ee15e022a', '3081b3b287', '30ee1343c5', '312be3dd62', '35cc01fce2', '3686367e00', '36a3fd1c9e', '373fdfbb8b', '37c196e828', '3a30436622', '3c663079fd', '3cdd09657a', '3d1ced3465', '3e686bbea6', '40e80d2208', '411cf7f936', '41622e9c80', '41c1dd6b32', '4286ba8bbb', '431c06de39', '4763278509', '496a95edd6', '4a6de23968', '4b2d936ea1', '4b656594ae', '4b9fbc8c46', '4e3efb8986', '4e4250b43e', '505d036de1', '55033cea2d', '55356264dc', '55378c4e31', '56425be165', '56be0aee75', '58146e2d7d', '58d96e1b15', '5911b54563', '5ad570d54d', '5af6c7af76', '5c14423c95', '5d1f365993', '5f22baf386', '5ff5745eeb', '6098a1404b', '60c520d794', '60c5a8b0f5', '62db6d3a84', '641d2d0b44', '64899df9fb', '6521c26493', '65fd0db978', '66cd91490e', '6c24bc22fd', '723bc74486', '72c4cf663e', '72d0ab7145', '749093c073', '766b6a7cbf', '7727f9b9db', '7a2687337d', '7ac2f5adbd', '7b9ca06591', '7c2b59a5e3', '7d0e395103', '7d84c658ea', '7d9a4f28dd', '7ecb115d14', '7efc323395', '81a7d2ffc5', '83832621ef', '85555b6355', '868ee4d7b6', '86ec1277b4', '8718c224c3', '8a093d875c', '8a151acca9', '8a39b6c4ca', '8c1e63a490', '8c38a7540a', '8cc03162f7', '8cc22cf43e', '8d4f5f12f6', '8d74193052', '8e35b61b56', '8f0d58b7a8', '8f2e1d7ff2', '8f360bf806', '9080fbe705',
# ## Some more qualitative recommendation evaluations

# %% [markdown]
# ### Some meaty recipe

# %%
recipe_ids = ["00b2b2edbd"]

recip = getRecipeFromComments(recipe_ids[0], extended_recipes)

bayes_naive_recommendations = getNaiveBayesRecommendations(recipe_ids, extended_recipes, recipe_ingredient_counts, recipe_ingredient_pair_counts)

direct_source_mutual_info_recommendations, cosine_similarity_role_recommendations, euclidean_similarity_role_recommendations, manhatten_similarity_role_recommendations = getRecommendationsBasedOnMutualInformationRole(recipe_ids, extended_recipes, mutual_info_dict)

_, cosine_similarity_role_recommendations_sq, euclidean_similarity_role_recommendations_sq, manhatten_similarity_role_recommendations_sq = getRecommendationsBasedOnMutualInformationRole(recipe_ids, extended_recipes, mutual_info_dict, normalization="dampen_square")

_, cosine_similarity_role_recommendations_minimax, euclidean_similarity_role_recommendations_minimax, manhatten_similarity_role_recommendations_minimax = getRecommendationsBasedOnMutualInformationRole(recipe_ids, extended_recipes, mutual_info_dict, normalization="minmax")

_, _2, euclidean_similarity_role_recommendations_ind_squared, manhatten_similarity_role_recommendations_ind_squared = getRecommendationsBasedOnMutualInformationRole(recipe_ids, extended_recipes, mutual_info_dict, normalization=None, limiter_indiv_ingr_distance="factor")

print(f"gt_sub = ({recip['subs']})  ")
print(f"recipe_ingredients: {recip['ingredients']}")
print("===")
print(f"direct_mi = {list(direct_source_mutual_info_recommendations[recipe_ids[0]].items())[:15]}")
print("===")
print(cosine_similarity_role_recommendations[recipe_ids[0]][:15])
print(euclidean_similarity_role_recommendations[recipe_ids[0]][:15])
print(manhatten_similarity_role_recommendations[recipe_ids[0]][:15])
print("===")
print(cosine_similarity_role_recommendations_sq[recipe_ids[0]][:15])
print(euclidean_similarity_role_recommendations_sq[recipe_ids[0]][:15])
print(manhatten_similarity_role_recommendations_sq[recipe_ids[0]][:15])
print("===")
print(cosine_similarity_role_recommendations_minimax[recipe_ids[0]][:15])
print(euclidean_similarity_role_recommendations_minimax[recipe_ids[0]][:15])
print(manhatten_similarity_role_recommendations_minimax[recipe_ids[0]][:15])
print("===")
print(euclidean_similarity_role_recommendations_ind_squared[recipe_ids[0]][:15])
print(manhatten_similarity_role_recommendations_ind_squared[recipe_ids[0]][:15])
# Out:
# gt_sub = ([('oregano', 'seasoning'), ('ground_beef', 'ground_turkey'), ('ground_beef', 'ground_sausage'), ('ground_beef', 'parmesan_cheese'), ('mild_cheddar_cheese', 'italian_seasoning'), ('ground_beef', 'turkey_sausage'), ('ground_beef', 'turkey')])
# recipe_ingredients: [['thin_spaghetti'], ['ground_beef'], ['garlic', 'garlic_sprouts'], ['spaghetti_sauce', 'garden_vegetable_spaghetti_sauce'], ['mild_cheddar_cheese', 'caerphilly_cheese'], ['oregano']]
# ===
# direct_mi = [('onion', 0.014479357808449611), ('tomato_sauce', 0.008368351296412911), ('pepper', 0.004044852631508548), ('ketchup', 0.003928400517292704), ('green_pepper', 0.0037516395648175514), ('baking_powder', 0.0033971881356922454), ('taco_seasoning', 0.003339181988187582), ('chili_powder', 0.0033094928231676216), ('worcestershire_sauce', 0.003274712699829152), ('baking_soda', 0.0031863102241034783), ('mozzarella_cheese', 0.003107582660396964), ('shredded_cheddar_cheese', 0.0028600424422341383), ('vanilla', 0.0026285105281725132), ('tomato_paste', 0.0025605138856730734), ('butter', 0.0024868891518025522)]
# ===
